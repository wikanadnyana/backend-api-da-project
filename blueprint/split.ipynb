# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/data2.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        date   time         round  day venue  \
# 0             0           6  2017-09-17  13:30   Matchweek 5  Sun  Away
# 1             1          10  2017-10-01  12:00   Matchweek 7  Sun  Home
# 2             2          13  2017-10-22  13:30   Matchweek 9  Sun  Away
# 3             3          17  2017-11-05  14:15  Matchweek 11  Sun  Away
# 4             4          18  2017-11-18  12:30  Matchweek 12  Sat  Home
#
#   result   gf   ga  ... day_code  gf_rolling  ga_rolling  sh_rolling  \
# 0      D  0.0  0.0  ...        6    2.333333    2.333333   17.333333
# 1      W  2.0  0.0  ...        6    1.000000    1.333333   12.000000
# 2      W  5.0  2.0  ...        6    1.666667    0.000000   17.666667
# 3      L  1.0  3.0  ...        6    2.333333    0.666667   22.000000
# 4      W  2.0  0.0  ...        5    2.666667    1.666667   20.333333
#
#    sot_rolling dist_rolling fk_rolling pk_rolling pkatt_rolling  home_code
# ...

# %%
del df["Unnamed: 0.1"]

# %%
del df["Unnamed: 0"]

# %%
df["day_code"].unique()
# Out:
# array([6, 5, 2, 4, 3, 0, 1], dtype=int64)

# %%
df = df.drop(columns=["time", "day", "result", "opponent", "captain", "referee", "match report", "attendance"])
df
# Out:
#             date         round venue   gf   ga   xg  xga  poss formation  \
# 0     2017-09-17   Matchweek 5  Away  0.0  0.0  1.4  0.8  49.0     3-4-3
# 1     2017-10-01   Matchweek 7  Home  2.0  0.0  2.4  0.4  64.0     3-4-3
# 2     2017-10-22   Matchweek 9  Away  5.0  2.0  3.5  1.0  67.0     3-4-3
# 3     2017-11-05  Matchweek 11  Away  1.0  3.0  0.3  1.8  43.0     3-4-3
# 4     2017-11-18  Matchweek 12  Home  2.0  0.0  2.1  0.7  43.0     3-4-3
# ...          ...           ...   ...  ...  ...  ...  ...   ...       ...
# 2953  2023-03-12  Matchweek 27  Away  1.0  2.0  1.1  1.8  57.0   4-2-3-1
# 2954  2023-03-18  Matchweek 28  Home  2.0  4.0  2.7  1.6  65.0     4-3-3
# 2955  2023-04-01  Matchweek 29  Away  1.0  1.0  0.5  1.3  71.0   4-2-3-1
# 2956  2023-04-08  Matchweek 30  Home  1.0  0.0  0.6  1.1  38.0     4-4-2
# 2957  2023-04-15  Matchweek 31  Home  2.0  0.0  0.8  1.1  50.0     4-4-2
#
#         sh  ...  day_code  gf_rolling  ga_rolling  sh_rolling  sot_rolling  \
# ...

# %%
df["formation"] = df["formation"].astype("category").cat.codes

# %%
df[df["formation"] == 5]
# Out:
#             date         round venue   gf   ga   xg  xga  poss  formation  \
# 1807  2020-12-26  Matchweek 15  Home  2.0  0.0  3.0  0.3  74.0          5
#
#         sh  ...  day_code  gf_rolling  ga_rolling  sh_rolling  sot_rolling  \
# 1807  11.0  ...         5         1.0         0.0   11.333333     3.666667
#
#       dist_rolling fk_rolling  pk_rolling  pkatt_rolling  home_code
# 1807          18.1   0.333333    0.333333       0.333333         12
#
# [1 rows x 33 columns]

# %%
df["round"] = df["round"].astype("category").cat.codes

# %%
df["round"].unique()
# Out:
# array([33, 35, 37,  2,  3,  6,  7,  8,  9, 10, 12, 14, 15, 16, 18, 19, 20,
#        21, 26, 27, 28, 29, 24,  0, 11, 22, 34, 36,  1,  4,  5, 13, 17, 23,
#        25, 30, 32, 31], dtype=int8)

# %%
df["round"].value_counts()
# Out:
# 7     88
# 1     86
# 13    86
# 8     86
# 36    85
# 35    85
# 14    84
# 21    84
# 19    84
# 15    84
# 10    84
# 3     84
# 2     84
# 12    82
# 34    82
# 16    82
# 9     82
# 23    82
# 6     82
# 4     82
# 17    82
# 24    81
# 18    80
# 5     80
# 37    80
# 33    79
# 20    76
# 32    72
# 22    70
# 11    68
# 0     66
# 28    66
# 26    66
# 27    65
# 31    64
# 25    63
# 30    62
# 29    60
# Name: round, dtype: int64

# %%
df["venue"] = df["venue"].astype("category").cat.codes
df["venue"].value_counts()
# Out:
# 1    1481
# 0    1477
# Name: venue, dtype: int64

# %%
target_home = df.pop("target_home")
target_away = df.pop("target_away")
target_draw = df.pop("target_draw")

# %%
df.insert(len(df.columns), "target_away", target_away)
df.insert(len(df.columns), "target_draw", target_draw)
df.insert(len(df.columns), "target_home", target_home)

# %%
df["team"]
# Out:
# 0       Arsenal
# 1       Arsenal
# 2       Arsenal
# 3       Arsenal
# 4       Arsenal
#          ...
# 2953     Wolves
# 2954     Wolves
# 2955     Wolves
# 2956     Wolves
# 2957     Wolves
# Name: team, Length: 2958, dtype: object

# %%
# df["team"] = df["team"].astype("category").cat.codes
# df["team"]
df["home_code"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 2953    19
# 2954    19
# 2955    19
# 2956    19
# 2957    19
# Name: home_code, Length: 2958, dtype: int64

# %%
# df.to_csv("../data/data3.csv")

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns()
#
# NameError: name 'df' is not defined

# %%
# Mengubah kolom date menjadi tipe data date
df['date'] = pd.to_datetime(df['date']).dt.date
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2958 entries, 0 to 2957
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           2958 non-null   object
#  1   round          2958 non-null   int8
#  2   venue          2958 non-null   int8
#  3   gf             2958 non-null   float64
#  4   ga             2958 non-null   float64
#  5   xg             2958 non-null   float64
#  6   xga            2958 non-null   float64
#  7   poss           2958 non-null   float64
#  8   formation      2958 non-null   int8
#  9   sh             2958 non-null   float64
#  10  sot            2958 non-null   float64
#  11  dist           2956 non-null   float64
#  12  fk             2958 non-null   float64
#  13  pk             2958 non-null   float64
#  14  pkatt          2958 non-null   float64
#  15  season         2958 non-null   int64
#  16  venue_code     2958 non-null   int64
# ...

# %%
df
# Out:
#             date  round  venue   gf   ga   xg  xga  poss  formation    sh  \
# 0     2017-09-17     33      0  0.0  0.0  1.4  0.8  49.0          4  11.0
# 1     2017-10-01     35      1  2.0  0.0  2.4  0.4  64.0          4  25.0
# 2     2017-10-22     37      0  5.0  2.0  3.5  1.0  67.0          4  30.0
# 3     2017-11-05      2      0  1.0  3.0  0.3  1.8  43.0          4   6.0
# 4     2017-11-18      3      1  2.0  0.0  2.1  0.7  43.0          4  14.0
# ...          ...    ...    ...  ...  ...  ...  ...   ...        ...   ...
# 2953  2023-03-12     19      0  1.0  2.0  1.1  1.8  57.0         12   7.0
# 2954  2023-03-18     20      1  2.0  4.0  2.7  1.6  65.0         15  23.0
# 2955  2023-04-01     21      0  1.0  1.0  0.5  1.3  71.0         12   8.0
# 2956  2023-04-08     23      1  1.0  0.0  0.6  1.1  38.0         17   9.0
# 2957  2023-04-15     24      1  2.0  0.0  0.8  1.1  50.0         17  11.0
#
#       ...  sh_rolling  sot_rolling  dist_rolling  fk_rolling  pk_rolling  \
# ...

# %%
del df["season"]
del df["target_draw"]
del df["target_away"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2958 entries, 0 to 2957
# Data columns (total 29 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           2958 non-null   object
#  1   round          2958 non-null   int8
#  2   venue          2958 non-null   int8
#  3   gf             2958 non-null   float64
#  4   ga             2958 non-null   float64
#  5   xg             2958 non-null   float64
#  6   xga            2958 non-null   float64
#  7   poss           2958 non-null   float64
#  8   formation      2958 non-null   int8
#  9   sh             2958 non-null   float64
#  10  sot            2958 non-null   float64
#  11  dist           2956 non-null   float64
#  12  fk             2958 non-null   float64
#  13  pk             2958 non-null   float64
#  14  pkatt          2958 non-null   float64
#  15  venue_code     2958 non-null   int64
#  16  opp_code       2958 non-null   int64
# ...

# %%
df
# Out:
#             date  round  venue   gf   ga   xg  xga  poss  formation    sh  \
# 0     2017-09-17     33      0  0.0  0.0  1.4  0.8  49.0          4  11.0
# 1     2017-10-01     35      1  2.0  0.0  2.4  0.4  64.0          4  25.0
# 2     2017-10-22     37      0  5.0  2.0  3.5  1.0  67.0          4  30.0
# 3     2017-11-05      2      0  1.0  3.0  0.3  1.8  43.0          4   6.0
# 4     2017-11-18      3      1  2.0  0.0  2.1  0.7  43.0          4  14.0
# ...          ...    ...    ...  ...  ...  ...  ...   ...        ...   ...
# 2953  2023-03-12     19      0  1.0  2.0  1.1  1.8  57.0         12   7.0
# 2954  2023-03-18     20      1  2.0  4.0  2.7  1.6  65.0         15  23.0
# 2955  2023-04-01     21      0  1.0  1.0  0.5  1.3  71.0         12   8.0
# 2956  2023-04-08     23      1  1.0  0.0  0.6  1.1  38.0         17   9.0
# 2957  2023-04-15     24      1  2.0  0.0  0.8  1.1  50.0         17  11.0
#
#       ...  gf_rolling  ga_rolling  sh_rolling  sot_rolling  dist_rolling  \
# ...

# %%
df.to_csv("../data/masterdata.csv")

# %%
train = df[df["season"] < '2021']
test = df[df["season"] > '2021']

# %%
train
# Out:
#       round  venue   gf   ga   xg  xga  poss  formation    sh   sot  ...  \
# 0        33      0  0.0  0.0  1.4  0.8  49.0          4  11.0   2.0  ...
# 1        35      1  2.0  0.0  2.4  0.4  64.0          4  25.0   8.0  ...
# 2        37      0  5.0  2.0  3.5  1.0  67.0          4  30.0  14.0  ...
# 3         2      0  1.0  3.0  0.3  1.8  43.0          4   6.0   3.0  ...
# 4         3      1  2.0  0.0  2.1  0.7  43.0          4  14.0   5.0  ...
# ...     ...    ...  ...  ...  ...  ...   ...        ...   ...   ...  ...
# 2890     24      0  1.0  0.0  0.5  0.9  50.0         12   7.0   3.0  ...
# 2891     28      1  2.0  1.0  1.1  0.3  61.0         12  16.0   6.0  ...
# 2892     29      0  0.0  2.0  0.9  3.2  38.0         12  15.0   3.0  ...
# 2893     30      0  0.0  1.0  0.3  0.7  59.0          3   9.0   3.0  ...
# 2894     31      1  1.0  2.0  0.9  2.0  57.0          7  14.0   4.0  ...
#
#       sh_rolling  sot_rolling  dist_rolling  fk_rolling pk_rolling  \
# ...

# %%
test
# Out:
#       round  venue   gf   ga   xg  xga  poss  formation    sh  sot  ...  \
# 147       0      0  2.0  0.0  1.0  1.2  44.0         15  10.0  2.0  ...
# 148      11      1  4.0  2.0  2.7  0.5  50.0         15  19.0  7.0  ...
# 149      22      0  3.0  0.0  1.3  0.3  57.0         15  14.0  6.0  ...
# 150      32      1  2.0  1.0  2.6  0.8  71.0         15  22.0  8.0  ...
# 151      33      1  2.0  1.0  2.4  0.4  59.0         15  22.0  8.0  ...
# ...     ...    ...  ...  ...  ...  ...   ...        ...   ...  ...  ...
# 2953     19      0  1.0  2.0  1.1  1.8  57.0         12   7.0  4.0  ...
# 2954     20      1  2.0  4.0  2.7  1.6  65.0         15  23.0  8.0  ...
# 2955     21      0  1.0  1.0  0.5  1.3  71.0         12   8.0  1.0  ...
# 2956     23      1  1.0  0.0  0.6  1.1  38.0         17   9.0  4.0  ...
# 2957     24      1  2.0  0.0  0.8  1.1  50.0         17  11.0  9.0  ...
#
#       sh_rolling  sot_rolling  dist_rolling  fk_rolling pk_rolling  \
# ...

# %%
train.to_csv("../data/traindata.csv")

# %%
test.to_csv("../data/testdata.csv")
